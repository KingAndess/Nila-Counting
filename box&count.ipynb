# %%
from ultralytics import YOLO
import cv2

# Load model
model = YOLO('/home/andes/skripsi/Nila-Counting/runs/train/E50B8/weights/best.pt')  # Ganti dengan path ke model best.pt Anda

# Baca video
video_path = '/home/andes/skripsi/Nila-Counting/Test-Vid/177.mp4'  # Ganti dengan path video yang ingin diuji
cap = cv2.VideoCapture(video_path)

# Mendapatkan ukuran frame untuk output video
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Output video
out = cv2.VideoWriter('177.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Melakukan inferensi pada setiap frame
    results = model.predict(frame, save=False)  # Prediksi tanpa menyimpan otomatis
    
    # Hitung jumlah deteksi (jumlah bounding box yang ditemukan)
    count = 0  # Inisialisasi perhitungan jumlah bibit ikan
    for result in results:
        count = len(result.boxes)  # Hitung jumlah box deteksi

        # Gambar bounding box tanpa label
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)  # Bounding box kuning

    # Tampilkan jumlah bibit ikan yang terdeteksi di layar
    text = f'total number of seeds detected: {count}'
    
    # Lokasi teks
    org = (20, 40)
    
    # Tambahkan shadow (teks hitam di belakang)
    cv2.putText(frame, text, (org[0] + 2, org[1] + 2), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 0, 0), 4)  # Bayangan hitam, tebal 4 px
    
    # Tambahkan teks putih di atas shadow (Bold dengan ketebalan lebih)
    cv2.putText(frame, text, org, cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 0, 255), 3)  # Teks merah, tebal 3 px

    # Simpan frame dengan bounding box dan jumlah deteksi
    out.write(frame)

    # Tampilkan hasil secara langsung (opsional)
    cv2.imshow('YOLOv10 Inference', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Melepaskan resource
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x608 169 BibitNilas, 130.5ms
# Speed: 21.1ms preprocess, 130.5ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 23.9ms
# Speed: 28.8ms preprocess, 23.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 20.9ms
# Speed: 6.0ms preprocess, 20.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 184 BibitNilas, 32.6ms
# Speed: 9.6ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 179 BibitNilas, 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 16.3ms
# Speed: 4.0ms preprocess, 16.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 163 BibitNilas, 11.3ms
# Speed: 4.9ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 179 BibitNilas, 12.5ms
# Speed: 3.4ms preprocess, 12.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 166 BibitNilas, 15.1ms
# Speed: 4.7ms preprocess, 15.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 10.9ms
# Speed: 3.6ms preprocess, 10.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 175 BibitNilas, 12.2ms
# Speed: 2.6ms preprocess, 12.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 178 BibitNilas, 11.2ms
# Speed: 2.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 185 BibitNilas, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 10.3ms
# Speed: 2.8ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 180 BibitNilas, 11.1ms
# Speed: 2.7ms preprocess, 11.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 183 BibitNilas, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 168 BibitNilas, 12.7ms
# Speed: 2.8ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 180 BibitNilas, 9.9ms
# Speed: 3.5ms preprocess, 9.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 178 BibitNilas, 10.2ms
# Speed: 3.5ms preprocess, 10.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 197 BibitNilas, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 183 BibitNilas, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 185 BibitNilas, 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 173 BibitNilas, 11.2ms
# Speed: 2.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 11.5ms
# Speed: 2.8ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 175 BibitNilas, 13.0ms
# Speed: 2.8ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 175 BibitNilas, 11.1ms
# Speed: 2.9ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 14.9ms
# Speed: 3.0ms preprocess, 14.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 180 BibitNilas, 13.1ms
# Speed: 3.3ms preprocess, 13.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 161 BibitNilas, 14.4ms
# Speed: 3.4ms preprocess, 14.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 31.4ms
# Speed: 4.1ms preprocess, 31.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 30.8ms
# Speed: 4.3ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 185 BibitNilas, 31.7ms
# Speed: 2.5ms preprocess, 31.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 13.1ms
# Speed: 3.4ms preprocess, 13.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 11.8ms
# Speed: 2.5ms preprocess, 11.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 175 BibitNilas, 14.7ms
# Speed: 2.6ms preprocess, 14.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 178 BibitNilas, 11.4ms
# Speed: 4.3ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 182 BibitNilas, 10.8ms
# Speed: 5.0ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 180 BibitNilas, 14.3ms
# Speed: 3.0ms preprocess, 14.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 29.1ms
# Speed: 5.4ms preprocess, 29.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 168 BibitNilas, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 175 BibitNilas, 15.1ms
# Speed: 4.1ms preprocess, 15.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 168 BibitNilas, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 165 BibitNilas, 11.9ms
# Speed: 2.9ms preprocess, 11.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 11.7ms
# Speed: 5.0ms preprocess, 11.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 11.1ms
# Speed: 3.1ms preprocess, 11.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 10.5ms
# Speed: 2.4ms preprocess, 10.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 11.5ms
# Speed: 2.9ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 164 BibitNilas, 14.7ms
# Speed: 3.2ms preprocess, 14.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 12.2ms
# Speed: 2.6ms preprocess, 12.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 25.6ms
# Speed: 3.9ms preprocess, 25.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 11.4ms
# Speed: 3.7ms preprocess, 11.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 165 BibitNilas, 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 14.4ms
# Speed: 2.7ms preprocess, 14.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 169 BibitNilas, 12.9ms
# Speed: 2.5ms preprocess, 12.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 173 BibitNilas, 12.9ms
# Speed: 2.6ms preprocess, 12.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 10.7ms
# Speed: 4.8ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 12.0ms
# Speed: 3.5ms preprocess, 12.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 32.0ms
# Speed: 3.3ms preprocess, 32.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 32.3ms
# Speed: 5.2ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 25.6ms
# Speed: 3.9ms preprocess, 25.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 27.8ms
# Speed: 4.2ms preprocess, 27.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 17.3ms
# Speed: 3.5ms preprocess, 17.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 181 BibitNilas, 12.0ms
# Speed: 2.8ms preprocess, 12.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 25.9ms
# Speed: 2.6ms preprocess, 25.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 179 BibitNilas, 36.9ms
# Speed: 4.3ms preprocess, 36.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 31.5ms
# Speed: 2.5ms preprocess, 31.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 168 BibitNilas, 10.1ms
# Speed: 2.4ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608
9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 188 BibitNilas, 25.1ms
# Speed: 3.8ms preprocess, 25.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 188 BibitNilas, 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 12.6ms
# Speed: 2.4ms preprocess, 12.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 12.9ms
# Speed: 2.5ms preprocess, 12.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 184 BibitNilas, 27.8ms
# Speed: 2.6ms preprocess, 27.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 182 BibitNilas, 11.2ms
# Speed: 2.5ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 11.3ms
# Speed: 2.7ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 167 BibitNilas, 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 166 BibitNilas, 12.9ms
# Speed: 2.5ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 161 BibitNilas, 12.3ms
# Speed: 2.8ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 167 BibitNilas, 30.3ms
# Speed: 2.4ms preprocess, 30.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 12.2ms
# Speed: 3.9ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 12.2ms
# Speed: 3.5ms preprocess, 12.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 13.1ms
# Speed: 2.6ms preprocess, 13.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 26.8ms
# Speed: 3.7ms preprocess, 26.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 13.5ms
# Speed: 3.4ms preprocess, 13.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 178 BibitNilas, 17.2ms
# Speed: 3.2ms preprocess, 17.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 178 BibitNilas, 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 13.2ms
# Speed: 2.6ms preprocess, 13.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 179 BibitNilas, 13.4ms
# Speed: 2.8ms preprocess, 13.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 30.5ms
# Speed: 3.5ms preprocess, 30.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 185 BibitNilas, 31.9ms
# Speed: 3.5ms preprocess, 31.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 180 BibitNilas, 30.6ms
# Speed: 3.8ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 29.5ms
# Speed: 4.3ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 180 BibitNilas, 29.5ms
# Speed: 4.5ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 178 BibitNilas, 30.4ms
# Speed: 3.8ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 180 BibitNilas, 29.2ms
# Speed: 3.8ms preprocess, 29.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 181 BibitNilas, 32.4ms
# Speed: 4.8ms preprocess, 32.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 182 BibitNilas, 28.5ms
# Speed: 3.9ms preprocess, 28.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 169 BibitNilas, 31.0ms
# Speed: 3.7ms preprocess, 31.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 167 BibitNilas, 28.1ms
# Speed: 3.6ms preprocess, 28.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 27.9ms
# Speed: 4.2ms preprocess, 27.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 166 BibitNilas, 29.5ms
# Speed: 4.0ms preprocess, 29.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 168 BibitNilas, 26.0ms
# Speed: 3.4ms preprocess, 26.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 178 BibitNilas, 15.9ms
# Speed: 2.5ms preprocess, 15.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 12.2ms
# Speed: 2.9ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 181 BibitNilas, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 168 BibitNilas, 10.3ms
# Speed: 3.4ms preprocess, 10.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 181 BibitNilas, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 175 BibitNilas, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 186 BibitNilas, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 9.6ms
# Speed: 3.3ms preprocess, 9.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 166 BibitNilas, 11.8ms
# Speed: 3.1ms preprocess, 11.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 24.7ms
# Speed: 2.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 168 BibitNilas, 27.4ms
# Speed: 2.8ms preprocess, 27.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 169 BibitNilas, 12.1ms
# Speed: 2.8ms preprocess, 12.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 10.3ms
# Speed: 2.7ms preprocess, 10.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 12.0ms
# Speed: 2.6ms preprocess, 12.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 175 BibitNilas, 17.4ms
# Speed: 2.6ms preprocess, 17.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 11.5ms
# Speed: 2.9ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 169 BibitNilas, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 170 BibitNilas, 11.8ms
# Speed: 2.3ms preprocess, 11.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 21.8ms
# Speed: 2.5ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 173 BibitNilas, 13.8ms
# Speed: 3.0ms preprocess, 13.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 173 BibitNilas, 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 13.1ms
# Speed: 2.6ms preprocess, 13.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 162 BibitNilas, 26.5ms
# Speed: 2.6ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 167 BibitNilas, 31.7ms
# Speed: 3.4ms preprocess, 31.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 33.0ms
# Speed: 3.9ms preprocess, 33.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 177 BibitNilas, 28.6ms
# Speed: 3.8ms preprocess, 28.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 174 BibitNilas, 29.8ms
# Speed: 3.4ms preprocess, 29.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 172 BibitNilas, 28.4ms
# Speed: 3.5ms preprocess, 28.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 182 BibitNilas, 28.9ms
# Speed: 3.5ms preprocess, 28.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 166 BibitNilas, 29.8ms
# Speed: 3.6ms preprocess, 29.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 175 BibitNilas, 28.7ms
# Speed: 3.9ms preprocess, 28.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 17.1ms
# Speed: 4.1ms preprocess, 17.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 169 BibitNilas, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 164 BibitNilas, 26.9ms
# Speed: 2.5ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 169 BibitNilas, 11.2ms
# Speed: 2.5ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 178 BibitNilas, 17.9ms
# Speed: 2.5ms preprocess, 17.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 168 BibitNilas, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 166 BibitNilas, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 169 BibitNilas, 11.8ms
# Speed: 2.5ms preprocess, 11.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 171 BibitNilas, 15.8ms
# Speed: 2.8ms preprocess, 15.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 169 BibitNilas, 22.2ms
# Speed: 2.5ms preprocess, 22.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 166 BibitNilas, 29.6ms
# Speed: 3.3ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 166 BibitNilas, 29.8ms
# Speed: 3.6ms preprocess, 29.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 166 BibitNilas, 29.5ms
# Speed: 3.0ms preprocess, 29.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 20.6ms
# Speed: 2.4ms preprocess, 20.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 175 BibitNilas, 15.7ms
# Speed: 4.2ms preprocess, 15.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 12.0ms
# Speed: 2.9ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 187 BibitNilas, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 191 BibitNilas, 29.6ms
# Speed: 2.7ms preprocess, 29.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 181 BibitNilas, 25.4ms
# Speed: 2.5ms preprocess, 25.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 190 BibitNilas, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 180 BibitNilas, 30.5ms
# Speed: 2.4ms preprocess, 30.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 181 BibitNilas, 14.8ms
# Speed: 3.4ms preprocess, 14.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 182 BibitNilas, 13.7ms
# Speed: 3.2ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 179 BibitNilas, 14.4ms
# Speed: 2.6ms preprocess, 14.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 14.3ms
# Speed: 2.6ms preprocess, 14.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 176 BibitNilas, 28.7ms
# Speed: 3.1ms preprocess, 28.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
