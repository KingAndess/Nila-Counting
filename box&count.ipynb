# %%
from ultralytics import YOLO
import cv2

# Load model
model = YOLO('/home/andes/skripsi/Nila-Counting/runs/train/E200B32/weights/best.pt')  # Ganti dengan path ke model best.pt Anda

# Baca video
video_path = '/home/andes/skripsi/Nila-Counting/Test-Vid/52.mp4'  # Ganti dengan path video yang ingin diuji
cap = cv2.VideoCapture(video_path)

# Mendapatkan ukuran frame untuk output video
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Output video
out = cv2.VideoWriter('52.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Melakukan inferensi pada setiap frame
    results = model.predict(frame, save=False)  # Prediksi tanpa menyimpan otomatis
    
    # Hitung jumlah deteksi (jumlah bounding box yang ditemukan)
    count = 0  # Inisialisasi perhitungan jumlah bibit ikan
    for result in results:
        count = len(result.boxes)  # Hitung jumlah box deteksi

        # Gambar bounding box tanpa label
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Bounding box kuning

    # Tampilkan jumlah bibit ikan yang terdeteksi di layar
    text = f'total number of seeds detected: {count}'
    
    # Lokasi teks
    org = (20, 40)
    
    # Tambahkan shadow (teks hitam di belakang)
    cv2.putText(frame, text, (org[0] + 2, org[1] + 2), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 0, 0), 4)  # Bayangan hitam, tebal 4 px
    
    # Tambahkan teks putih di atas shadow (Bold dengan ketebalan lebih)
    cv2.putText(frame, text, org, cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 0, 255), 3)  # Teks merah, tebal 3 px

    # Simpan frame dengan bounding box dan jumlah deteksi
    out.write(frame)

    # Tampilkan hasil secara langsung (opsional)
    cv2.imshow('YOLOv10 Inference', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Melepaskan resource
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x512 52 BibitNilas, 21.6ms
# Speed: 3.1ms preprocess, 21.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 15.7ms
# Speed: 5.2ms preprocess, 15.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 14.2ms
# Speed: 2.3ms preprocess, 14.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 13.7ms
# Speed: 3.3ms preprocess, 13.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 BibitNilas, 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 48 BibitNilas, 11.4ms
# Speed: 3.1ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 9.8ms
# Speed: 3.5ms preprocess, 9.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 10.9ms
# Speed: 4.3ms preprocess, 10.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 10.8ms
# Speed: 5.9ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 48 BibitNilas, 8.7ms
# Speed: 3.4ms preprocess, 8.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 11.5ms
# Speed: 4.3ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 11.2ms
# Speed: 4.9ms preprocess, 11.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 8.4ms
# Speed: 3.2ms preprocess, 8.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 7.3ms
# Speed: 3.3ms preprocess, 7.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 9.8ms
# Speed: 2.2ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 49 BibitNilas, 9.3ms
# Speed: 4.6ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 19.4ms
# Speed: 4.6ms preprocess, 19.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 BibitNilas, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 BibitNilas, 26.0ms
# Speed: 3.1ms preprocess, 26.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 12.5ms
# Speed: 3.3ms preprocess, 12.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 9.3ms
# Speed: 3.1ms preprocess, 9.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 9.3ms
# Speed: 3.1ms preprocess, 9.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 9.6ms
# Speed: 3.2ms preprocess, 9.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 9.3ms
# Speed: 4.1ms preprocess, 9.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 11.9ms
# Speed: 3.0ms preprocess, 11.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 49 BibitNilas, 10.6ms
# Speed: 3.3ms preprocess, 10.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 48 BibitNilas, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 49 BibitNilas, 10.7ms
# Speed: 3.4ms preprocess, 10.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512
6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 27.7ms
# Speed: 2.4ms preprocess, 27.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 16.2ms
# Speed: 3.3ms preprocess, 16.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 10.4ms
# Speed: 2.2ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 9.3ms
# Speed: 2.3ms preprocess, 9.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 49 BibitNilas, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 13.3ms
# Speed: 7.8ms preprocess, 13.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 10.1ms
# Speed: 2.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 10.5ms
# Speed: 2.3ms preprocess, 10.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 BibitNilas, 10.5ms
# Speed: 2.9ms preprocess, 10.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 10.3ms
# Speed: 3.3ms preprocess, 10.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 9.8ms
# Speed: 3.2ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 BibitNilas, 11.5ms
# Speed: 2.9ms preprocess, 11.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 BibitNilas, 28.1ms
# Speed: 2.9ms preprocess, 28.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 11.9ms
# Speed: 2.6ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 10.2ms
# Speed: 3.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 11.4ms
# Speed: 3.0ms preprocess, 11.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 26.2ms
# Speed: 3.3ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 25.2ms
# Speed: 3.5ms preprocess, 25.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 25.7ms
# Speed: 3.5ms preprocess, 25.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 27.3ms
# Speed: 3.0ms preprocess, 27.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 BibitNilas, 19.7ms
# Speed: 2.4ms preprocess, 19.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 11.6ms
# Speed: 3.4ms preprocess, 11.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 14.3ms
# Speed: 3.8ms preprocess, 14.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 BibitNilas, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 9.4ms
# Speed: 2.6ms preprocess, 9.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 9.1ms
# Speed: 3.2ms preprocess, 9.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 13.1ms
# Speed: 2.6ms preprocess, 13.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 10.4ms
# Speed: 2.6ms preprocess, 10.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 10.1ms
# Speed: 2.4ms preprocess, 10.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 BibitNilas, 10.4ms
# Speed: 2.6ms preprocess, 10.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 11.3ms
# Speed: 2.6ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 BibitNilas, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 22.8ms
# Speed: 2.4ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 16.8ms
# Speed: 5.3ms preprocess, 16.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 9.6ms
# Speed: 3.4ms preprocess, 9.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 27.3ms
# Speed: 2.8ms preprocess, 27.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 11.0ms
# Speed: 3.3ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 11.5ms
# Speed: 2.6ms preprocess, 11.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 12.0ms
# Speed: 2.3ms preprocess, 12.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 BibitNilas, 25.6ms
# Speed: 2.8ms preprocess, 25.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 11.9ms
# Speed: 2.4ms preprocess, 11.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 11.6ms
# Speed: 2.4ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 27.0ms
# Speed: 2.4ms preprocess, 27.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 BibitNilas, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 12.5ms
# Speed: 2.4ms preprocess, 12.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 BibitNilas, 12.8ms
# Speed: 2.6ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 13.1ms
# Speed: 2.2ms preprocess, 13.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 BibitNilas, 12.2ms
# Speed: 2.3ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
